# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.0, high = 90.0, size = 2000)
lngs = np.random.uniform(low = -180.0, high = 180.0, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 728

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weatherdesc = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                          })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 1 | uyovu
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | aitape
# Processing Record 7 of Set 1 | talnakh
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | vestmanna
# Processing Record 12 of Set 1 | luanda
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | korla
# Processing Record 16 of Set 1 | bandarbeyla
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | clyde river
# Processing Record 21 of Set 1 | esperance
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | abu dhabi
# Processing Record 24 of Set 1 | saint-pierre
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | iranshahr
# Processing Record 27 of Set 1 | geraldton
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | east london
# Processing Record 33 of Set 1 | dongsheng
# Processing Record 34 of Set 1 | alvinopolis
# Processing Record 35 of Set 1 | bengkulu
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | korsor
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | aden
# Processing Record 40 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 1 | airai
# Processing Record 42 of Set 1 | lodwar
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | kaeo
# Processing Record 45 of Set 1 | kamariotissa
# Processing Record 46 of Set 1 | guerrero negro
# Processing Record 47 of Set 1 | hofn
# Processing Record 48 of Set 1 | remedios
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | plettenberg bay
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | letpadan
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | hamilton
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | ledyard
# Processing Record 8 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 2 | grootfontein
# Processing Record 10 of Set 2 | terrace bay
# Processing Record 11 of Set 2 | slave lake
# Processing Record 12 of Set 2 | bathsheba
# Processing Record 13 of Set 2 | ventspils
# Processing Record 14 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | te anau
# Processing Record 17 of Set 2 | camacha
# Processing Record 18 of Set 2 | iqaluit
# Processing Record 19 of Set 2 | laguna
# Processing Record 20 of Set 2 | pangnirtung
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | tandil
# Processing Record 23 of Set 2 | itarema
# Processing Record 24 of Set 2 | najran
# Processing Record 25 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 26 of Set 2 | kavieng
# Processing Record 27 of Set 2 | vostok
# Processing Record 28 of Set 2 | jeremoabo
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | komsomolskiy
# Processing Record 31 of Set 2 | aklavik
# Processing Record 32 of Set 2 | margate
# Processing Record 33 of Set 2 | fortuna
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | tessalit
# Processing Record 36 of Set 2 | bluff
# Processing Record 37 of Set 2 | pevek
# Processing Record 38 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 2 | provideniya
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 42 of Set 2 | pine bluff
# Processing Record 43 of Set 2 | waddan
# Processing Record 44 of Set 2 | upernavik
# Processing Record 45 of Set 2 | mandurah
# Processing Record 46 of Set 2 | weyburn
# Processing Record 47 of Set 2 | gao
# Processing Record 48 of Set 2 | nikolskoye
# Processing Record 49 of Set 2 | bilma
# Processing Record 50 of Set 2 | namibe
# Processing Record 1 of Set 3 | sao filipe
# Processing Record 2 of Set 3 | port hedland
# Processing Record 3 of Set 3 | benguela
# Processing Record 4 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 3 | alanya
# Processing Record 6 of Set 3 | alice springs
# Processing Record 7 of Set 3 | paamiut
# Processing Record 8 of Set 3 | vaitape
# Processing Record 9 of Set 3 | faya
# Processing Record 10 of Set 3 | eureka
# Processing Record 11 of Set 3 | sinnamary
# Processing Record 12 of Set 3 | aqtobe
# Processing Record 13 of Set 3 | kahului
# Processing Record 14 of Set 3 | sept-iles
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | kapaa
# Processing Record 17 of Set 3 | lebu
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | yarada
# Processing Record 20 of Set 3 | katsuura
# Processing Record 21 of Set 3 | broken hill
# Processing Record 22 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 3 | constitucion
# Processing Record 24 of Set 3 | malanje
# Processing Record 25 of Set 3 | taoudenni
# Processing Record 26 of Set 3 | qaqortoq
# Processing Record 27 of Set 3 | chokurdakh
# Processing Record 28 of Set 3 | macomer
# Processing Record 29 of Set 3 | uravakonda
# Processing Record 30 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 3 | lavrentiya
# Processing Record 32 of Set 3 | torbay
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | shubarshi
# Processing Record 35 of Set 3 | antsohihy
# Processing Record 36 of Set 3 | mecca
# Processing Record 37 of Set 3 | kutum
# Processing Record 38 of Set 3 | lagoa
# Processing Record 39 of Set 3 | tiksi
# Processing Record 40 of Set 3 | hithadhoo
# Processing Record 41 of Set 3 | salalah
# Processing Record 42 of Set 3 | olavarria
# Processing Record 43 of Set 3 | takoradi
# Processing Record 44 of Set 3 | chuy
# Processing Record 45 of Set 3 | tasiilaq
# Processing Record 46 of Set 3 | narsaq
# Processing Record 47 of Set 3 | saint george
# Processing Record 48 of Set 3 | naryan-mar
# Processing Record 49 of Set 3 | mar del plata
# Processing Record 50 of Set 3 | loandjili
# Processing Record 1 of Set 4 | namatanai
# Processing Record 2 of Set 4 | xai-xai
# Processing Record 3 of Set 4 | yenagoa
# Processing Record 4 of Set 4 | ust-tsilma
# Processing Record 5 of Set 4 | mahebourg
# Processing Record 6 of Set 4 | la presa
# Processing Record 7 of Set 4 | sampang
# Processing Record 8 of Set 4 | zhezkazgan
# Processing Record 9 of Set 4 | itamaraju
# Processing Record 10 of Set 4 | hazro
# Processing Record 11 of Set 4 | ancud
# Processing Record 12 of Set 4 | mount gambier
# Processing Record 13 of Set 4 | maumere
# Processing Record 14 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 4 | maromitsa
# Processing Record 16 of Set 4 | roura
# Processing Record 17 of Set 4 | byron bay
# Processing Record 18 of Set 4 | aasiaat
# Processing Record 19 of Set 4 | fort nelson
# Processing Record 20 of Set 4 | vostochnyy
# Processing Record 21 of Set 4 | mackay
# Processing Record 22 of Set 4 | moreira sales
# Processing Record 23 of Set 4 | julio de castilhos
# Processing Record 24 of Set 4 | berlevag
# Processing Record 25 of Set 4 | college
# Processing Record 26 of Set 4 | majene
# Processing Record 27 of Set 4 | vestmannaeyjar
# Processing Record 28 of Set 4 | longyearbyen
# Processing Record 29 of Set 4 | lasa
# Processing Record 30 of Set 4 | honiara
# Processing Record 31 of Set 4 | vizinga
# Processing Record 32 of Set 4 | tual
# Processing Record 33 of Set 4 | sitka
# Processing Record 34 of Set 4 | los aquijes
# Processing Record 35 of Set 4 | celestun
# Processing Record 36 of Set 4 | meulaboh
# Processing Record 37 of Set 4 | nijar
# Processing Record 38 of Set 4 | killybegs
# Processing Record 39 of Set 4 | sulphur
# Processing Record 40 of Set 4 | codrington
# Processing Record 41 of Set 4 | san quintin
# Processing Record 42 of Set 4 | at-bashi
# Processing Record 43 of Set 4 | tabas
# Processing Record 44 of Set 4 | coralville
# Processing Record 45 of Set 4 | denpasar
# Processing Record 46 of Set 4 | tuktoyaktuk
# Processing Record 47 of Set 4 | tecoanapa
# Processing Record 48 of Set 4 | balotra
# Processing Record 49 of Set 4 | thompson
# Processing Record 50 of Set 4 | shache
# Processing Record 1 of Set 5 | nanortalik
# Processing Record 2 of Set 5 | sterling
# Processing Record 3 of Set 5 | acapulco
# Processing Record 4 of Set 5 | makakilo city
# Processing Record 5 of Set 5 | manacapuru
# Processing Record 6 of Set 5 | kostino
# Processing Record 7 of Set 5 | portland
# Processing Record 8 of Set 5 | carnarvon
# Processing Record 9 of Set 5 | ostrovnoy
# Processing Record 10 of Set 5 | havre-saint-pierre
# Processing Record 11 of Set 5 | cuddapah
# Processing Record 12 of Set 5 | caravelas
# Processing Record 13 of Set 5 | sal rei
# Processing Record 14 of Set 5 | chicama
# Processing Record 15 of Set 5 | luderitz
# Processing Record 16 of Set 5 | saint-philippe
# Processing Record 17 of Set 5 | cherskiy
# Processing Record 18 of Set 5 | munsingen
# Processing Record 19 of Set 5 | pendleton
# Processing Record 20 of Set 5 | tarsus
# Processing Record 21 of Set 5 | kozhva
# Processing Record 22 of Set 5 | georgetown
# Processing Record 23 of Set 5 | redcliffe
# Processing Record 24 of Set 5 | muros
# Processing Record 25 of Set 5 | ciudad bolivar
# Processing Record 26 of Set 5 | aksu
# Processing Record 27 of Set 5 | podporozhye
# Processing Record 28 of Set 5 | bereda
# Processing Record 29 of Set 5 | zenzeli
# Processing Record 30 of Set 5 | okandja
# City not found. Skipping...
# Processing Record 31 of Set 5 | butaritari
# Processing Record 32 of Set 5 | itoman
# Processing Record 33 of Set 5 | mamallapuram
# Processing Record 34 of Set 5 | port elizabeth
# Processing Record 35 of Set 5 | coquimbo
# Processing Record 36 of Set 5 | jasper
# Processing Record 37 of Set 5 | pincher creek
# Processing Record 38 of Set 5 | la ronge
# Processing Record 39 of Set 5 | san cristobal
# Processing Record 40 of Set 5 | tambura
# Processing Record 41 of Set 5 | vaini
# Processing Record 42 of Set 5 | saldanha
# Processing Record 43 of Set 5 | alofi
# Processing Record 44 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 5 | ndouci
# City not found. Skipping...
# Processing Record 46 of Set 5 | atuona
# Processing Record 47 of Set 5 | eenhana
# Processing Record 48 of Set 5 | srednekolymsk
# Processing Record 49 of Set 5 | okhotsk
# Processing Record 50 of Set 5 | amapa
# Processing Record 1 of Set 6 | shenzhen
# Processing Record 2 of Set 6 | ahipara
# Processing Record 3 of Set 6 | lebedinyy
# Processing Record 4 of Set 6 | souillac
# Processing Record 5 of Set 6 | sao joao da barra
# Processing Record 6 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 7 of Set 6 | baker city
# Processing Record 8 of Set 6 | londoko
# Processing Record 9 of Set 6 | severo-kurilsk
# Processing Record 10 of Set 6 | rawson
# Processing Record 11 of Set 6 | lincoln
# Processing Record 12 of Set 6 | nyurba
# Processing Record 13 of Set 6 | kaka
# Processing Record 14 of Set 6 | wairoa
# Processing Record 15 of Set 6 | lorengau
# Processing Record 16 of Set 6 | haines junction
# Processing Record 17 of Set 6 | rosita
# Processing Record 18 of Set 6 | richards bay
# Processing Record 19 of Set 6 | paita
# Processing Record 20 of Set 6 | aykhal
# Processing Record 21 of Set 6 | klaksvik
# Processing Record 22 of Set 6 | maragogi
# Processing Record 23 of Set 6 | vila franca do campo
# Processing Record 24 of Set 6 | nome
# Processing Record 25 of Set 6 | cabo san lucas
# Processing Record 26 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 6 | liuzhou
# Processing Record 28 of Set 6 | ilulissat
# Processing Record 29 of Set 6 | elmadag
# Processing Record 30 of Set 6 | aleksandrov gay
# Processing Record 31 of Set 6 | lowestoft
# Processing Record 32 of Set 6 | kindu
# Processing Record 33 of Set 6 | ponta do sol
# Processing Record 34 of Set 6 | nishihara
# Processing Record 35 of Set 6 | sao carlos
# Processing Record 36 of Set 6 | orel
# Processing Record 37 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 6 | ahmadpur
# Processing Record 39 of Set 6 | teneguiban
# City not found. Skipping...
# Processing Record 40 of Set 6 | denison
# Processing Record 41 of Set 6 | asau
# Processing Record 42 of Set 6 | cabedelo
# Processing Record 43 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 6 | pobe
# Processing Record 45 of Set 6 | deputatskiy
# Processing Record 46 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 6 | manoel urbano
# Processing Record 48 of Set 6 | sobolevo
# Processing Record 49 of Set 6 | sovetsk
# Processing Record 50 of Set 6 | ajdabiya
# Processing Record 1 of Set 7 | kodiak
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | tlaxco
# Processing Record 4 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 5 of Set 7 | sola
# Processing Record 6 of Set 7 | zyryanka
# Processing Record 7 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 7 | cayenne
# Processing Record 9 of Set 7 | pangkalanbuun
# Processing Record 10 of Set 7 | pochutla
# Processing Record 11 of Set 7 | sovetskiy
# Processing Record 12 of Set 7 | karratha
# Processing Record 13 of Set 7 | kampot
# Processing Record 14 of Set 7 | antalaha
# Processing Record 15 of Set 7 | kalianget
# Processing Record 16 of Set 7 | bethel
# Processing Record 17 of Set 7 | kousseri
# Processing Record 18 of Set 7 | trincomalee
# Processing Record 19 of Set 7 | wollongong
# Processing Record 20 of Set 7 | isangel
# Processing Record 21 of Set 7 | port lincoln
# Processing Record 22 of Set 7 | tikrit
# Processing Record 23 of Set 7 | port keats
# Processing Record 24 of Set 7 | baghdad
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | outlook
# Processing Record 27 of Set 7 | zhicheng
# Processing Record 28 of Set 7 | beringovskiy
# Processing Record 29 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 7 | rovigo
# Processing Record 31 of Set 7 | payakumbuh
# Processing Record 32 of Set 7 | logan
# Processing Record 33 of Set 7 | mutsu
# Processing Record 34 of Set 7 | champerico
# Processing Record 35 of Set 7 | haverfordwest
# Processing Record 36 of Set 7 | roela
# Processing Record 37 of Set 7 | atar
# Processing Record 38 of Set 7 | russell
# Processing Record 39 of Set 7 | tautira
# Processing Record 40 of Set 7 | acarau
# Processing Record 41 of Set 7 | urucara
# Processing Record 42 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 7 | kovdor
# Processing Record 44 of Set 7 | harper
# Processing Record 45 of Set 7 | kaitangata
# Processing Record 46 of Set 7 | calabozo
# Processing Record 47 of Set 7 | carballo
# Processing Record 48 of Set 7 | clifton
# Processing Record 49 of Set 7 | freeport
# Processing Record 50 of Set 7 | marawi
# Processing Record 1 of Set 8 | cholet
# Processing Record 2 of Set 8 | leningradskiy
# Processing Record 3 of Set 8 | mian channun
# Processing Record 4 of Set 8 | rocha
# Processing Record 5 of Set 8 | bambous virieux
# Processing Record 6 of Set 8 | husavik
# Processing Record 7 of Set 8 | santiago del estero
# Processing Record 8 of Set 8 | teofilo otoni
# Processing Record 9 of Set 8 | pitimbu
# Processing Record 10 of Set 8 | liverpool
# Processing Record 11 of Set 8 | fayaoue
# Processing Record 12 of Set 8 | puka
# Processing Record 13 of Set 8 | kattivakkam
# Processing Record 14 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 8 | usinsk
# Processing Record 16 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 8 | pandamatenga
# Processing Record 18 of Set 8 | lisieux
# Processing Record 19 of Set 8 | nelson bay
# Processing Record 20 of Set 8 | faanui
# Processing Record 21 of Set 8 | henties bay
# Processing Record 22 of Set 8 | lushunkou
# City not found. Skipping...
# Processing Record 23 of Set 8 | loralai
# Processing Record 24 of Set 8 | salamiyah
# Processing Record 25 of Set 8 | saint-georges
# Processing Record 26 of Set 8 | artyom
# Processing Record 27 of Set 8 | prince rupert
# Processing Record 28 of Set 8 | bubaque
# Processing Record 29 of Set 8 | sandpoint
# Processing Record 30 of Set 8 | bayamo
# Processing Record 31 of Set 8 | leiyang
# Processing Record 32 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 33 of Set 8 | myatlevo
# Processing Record 34 of Set 8 | oksfjord
# Processing Record 35 of Set 8 | pahrump
# Processing Record 36 of Set 8 | liberal
# Processing Record 37 of Set 8 | yar-sale
# Processing Record 38 of Set 8 | pisco
# Processing Record 39 of Set 8 | bridlington
# Processing Record 40 of Set 8 | vardo
# Processing Record 41 of Set 8 | lompoc
# Processing Record 42 of Set 8 | yangcun
# Processing Record 43 of Set 8 | aswan
# Processing Record 44 of Set 8 | ponta delgada
# Processing Record 45 of Set 8 | lander
# Processing Record 46 of Set 8 | malysheva
# Processing Record 47 of Set 8 | tuatapere
# Processing Record 48 of Set 8 | coahuayana
# Processing Record 49 of Set 8 | knysna
# Processing Record 50 of Set 8 | yulara
# Processing Record 1 of Set 9 | mbalmayo
# Processing Record 2 of Set 9 | constanta
# Processing Record 3 of Set 9 | palmer
# Processing Record 4 of Set 9 | ullapool
# Processing Record 5 of Set 9 | rawdon
# Processing Record 6 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 9 | cap malheureux
# Processing Record 8 of Set 9 | frolovo
# Processing Record 9 of Set 9 | boca do acre
# Processing Record 10 of Set 9 | ghatanji
# Processing Record 11 of Set 9 | svetlogorsk
# Processing Record 12 of Set 9 | yichang
# Processing Record 13 of Set 9 | sechura
# Processing Record 14 of Set 9 | kruisfontein
# Processing Record 15 of Set 9 | san rafael
# Processing Record 16 of Set 9 | ulladulla
# Processing Record 17 of Set 9 | egvekinot
# Processing Record 18 of Set 9 | kishapu
# Processing Record 19 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 20 of Set 9 | zhigansk
# Processing Record 21 of Set 9 | soroti
# Processing Record 22 of Set 9 | starachowice
# Processing Record 23 of Set 9 | xuddur
# Processing Record 24 of Set 9 | altay
# Processing Record 25 of Set 9 | zelion
# City not found. Skipping...
# Processing Record 26 of Set 9 | ende
# Processing Record 27 of Set 9 | la estancia
# Processing Record 28 of Set 9 | aguimes
# Processing Record 29 of Set 9 | cockburn town
# Processing Record 30 of Set 9 | batemans bay
# Processing Record 31 of Set 9 | le moule
# Processing Record 32 of Set 9 | auki
# Processing Record 33 of Set 9 | avera
# Processing Record 34 of Set 9 | kupang
# Processing Record 35 of Set 9 | nabire
# Processing Record 36 of Set 9 | shuangyang
# Processing Record 37 of Set 9 | tatarsk
# Processing Record 38 of Set 9 | rognan
# Processing Record 39 of Set 9 | jiroft
# City not found. Skipping...
# Processing Record 40 of Set 9 | goderich
# Processing Record 41 of Set 9 | tiznit
# Processing Record 42 of Set 9 | touros
# Processing Record 43 of Set 9 | padang
# Processing Record 44 of Set 9 | winfield
# Processing Record 45 of Set 9 | omsukchan
# Processing Record 46 of Set 9 | tura
# Processing Record 47 of Set 9 | kursenai
# Processing Record 48 of Set 9 | nizwa
# Processing Record 49 of Set 9 | flin flon
# Processing Record 50 of Set 9 | dakar
# Processing Record 1 of Set 10 | saint anthony
# Processing Record 2 of Set 10 | iracoubo
# Processing Record 3 of Set 10 | seymchan
# Processing Record 4 of Set 10 | nioro
# Processing Record 5 of Set 10 | buguruslan
# Processing Record 6 of Set 10 | smithers
# Processing Record 7 of Set 10 | le port
# Processing Record 8 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 10 | birin
# Processing Record 10 of Set 10 | kapit
# Processing Record 11 of Set 10 | zhuanghe
# Processing Record 12 of Set 10 | sabang
# Processing Record 13 of Set 10 | suluq
# Processing Record 14 of Set 10 | blonduos
# City not found. Skipping...
# Processing Record 15 of Set 10 | thinadhoo
# Processing Record 16 of Set 10 | pacific grove
# Processing Record 17 of Set 10 | brae
# Processing Record 18 of Set 10 | salaga
# Processing Record 19 of Set 10 | anadyr
# Processing Record 20 of Set 10 | kitovo
# Processing Record 21 of Set 10 | port augusta
# Processing Record 22 of Set 10 | sao gabriel
# Processing Record 23 of Set 10 | redlands
# Processing Record 24 of Set 10 | fare
# Processing Record 25 of Set 10 | mao
# Processing Record 26 of Set 10 | sayyan
# Processing Record 27 of Set 10 | san andres
# Processing Record 28 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 10 | kenora
# Processing Record 30 of Set 10 | katyuzhanka
# Processing Record 31 of Set 10 | guadalupe y calvo
# Processing Record 32 of Set 10 | polyarnyy
# Processing Record 33 of Set 10 | udachnyy
# Processing Record 34 of Set 10 | hearst
# Processing Record 35 of Set 10 | antofagasta
# Processing Record 36 of Set 10 | victor harbor
# Processing Record 37 of Set 10 | boda
# Processing Record 38 of Set 10 | saint-joseph
# Processing Record 39 of Set 10 | manavadar
# Processing Record 40 of Set 10 | londa
# Processing Record 41 of Set 10 | leh
# Processing Record 42 of Set 10 | safaga
# Processing Record 43 of Set 10 | barabinsk
# Processing Record 44 of Set 10 | talcahuano
# Processing Record 45 of Set 10 | strathpeffer
# Processing Record 46 of Set 10 | samarai
# Processing Record 47 of Set 10 | formosa
# Processing Record 48 of Set 10 | clarksburg
# Processing Record 49 of Set 10 | san juan
# Processing Record 50 of Set 10 | khanion tou kokkini
# City not found. Skipping...
# Processing Record 1 of Set 11 | vargashi
# Processing Record 2 of Set 11 | mongoumba
# Processing Record 3 of Set 11 | lazaro cardenas
# Processing Record 4 of Set 11 | sergeyevka
# Processing Record 5 of Set 11 | westport
# Processing Record 6 of Set 11 | tocopilla
# Processing Record 7 of Set 11 | dryden
# Processing Record 8 of Set 11 | taltal
# Processing Record 9 of Set 11 | salinopolis
# Processing Record 10 of Set 11 | san-pedro
# Processing Record 11 of Set 11 | iquitos
# Processing Record 12 of Set 11 | wilmington
# Processing Record 13 of Set 11 | abu samrah
# Processing Record 14 of Set 11 | tabukiniberu
# City not found. Skipping...
# Processing Record 15 of Set 11 | hami
# Processing Record 16 of Set 11 | inuvik
# Processing Record 17 of Set 11 | ishigaki
# Processing Record 18 of Set 11 | pak phanang
# Processing Record 19 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 20 of Set 11 | yertsevo
# Processing Record 21 of Set 11 | mehamn
# Processing Record 22 of Set 11 | vengerovo
# Processing Record 23 of Set 11 | caucaia
# Processing Record 24 of Set 11 | jalu
# Processing Record 25 of Set 11 | gornopravdinsk
# Processing Record 26 of Set 11 | kirakira
# Processing Record 27 of Set 11 | dergachi
# Processing Record 28 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 11 | fairbanks
# Processing Record 30 of Set 11 | nanga eboko
# Processing Record 31 of Set 11 | mandera
# Processing Record 32 of Set 11 | zhangye
# Processing Record 33 of Set 11 | igbo ora
# Processing Record 34 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 11 | izhma
# Processing Record 36 of Set 11 | alashtar
# City not found. Skipping...
# Processing Record 37 of Set 11 | bodden town
# Processing Record 38 of Set 11 | vidim
# Processing Record 39 of Set 11 | gat
# Processing Record 40 of Set 11 | monteria
# Processing Record 41 of Set 11 | mareeba
# Processing Record 42 of Set 11 | katherine
# Processing Record 43 of Set 11 | quatre cocos
# Processing Record 44 of Set 11 | montes claros
# Processing Record 45 of Set 11 | ossora
# Processing Record 46 of Set 11 | kamyaran
# Processing Record 47 of Set 11 | jaffna
# Processing Record 48 of Set 11 | mount isa
# Processing Record 49 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 1 of Set 12 | iskateley
# Processing Record 2 of Set 12 | darovskoy
# Processing Record 3 of Set 12 | flinders
# Processing Record 4 of Set 12 | santa isabel do rio negro
# Processing Record 5 of Set 12 | grindavik
# Processing Record 6 of Set 12 | kieta
# Processing Record 7 of Set 12 | opobo
# City not found. Skipping...
# Processing Record 8 of Set 12 | alyangula
# Processing Record 9 of Set 12 | la asuncion
# Processing Record 10 of Set 12 | fereydunshahr
# Processing Record 11 of Set 12 | kamarion
# Processing Record 12 of Set 12 | axim
# Processing Record 13 of Set 12 | kungur
# Processing Record 14 of Set 12 | kavaratti
# Processing Record 15 of Set 12 | pascagoula
# Processing Record 16 of Set 12 | novosergiyevka
# Processing Record 17 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 12 | la huerta
# Processing Record 19 of Set 12 | rivadavia
# Processing Record 20 of Set 12 | marshalltown
# Processing Record 21 of Set 12 | sao felix do xingu
# Processing Record 22 of Set 12 | solhan
# Processing Record 23 of Set 12 | nakhon phanom
# Processing Record 24 of Set 12 | nemuro
# Processing Record 25 of Set 12 | mantua
# Processing Record 26 of Set 12 | pecos
# Processing Record 27 of Set 12 | stanghelle
# Processing Record 28 of Set 12 | cidreira
# Processing Record 29 of Set 12 | iwakuni
# Processing Record 30 of Set 12 | acara
# Processing Record 31 of Set 12 | maltahohe
# Processing Record 32 of Set 12 | rio gallegos
# Processing Record 33 of Set 12 | marzuq
# Processing Record 34 of Set 12 | chumikan
# Processing Record 35 of Set 12 | biltine
# Processing Record 36 of Set 12 | srivardhan
# Processing Record 37 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 38 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 12 | mankapur
# Processing Record 40 of Set 12 | chalus
# Processing Record 41 of Set 12 | chimbote
# Processing Record 42 of Set 12 | joshimath
# Processing Record 43 of Set 12 | bosaso
# Processing Record 44 of Set 12 | severnyy
# Processing Record 45 of Set 12 | awbari
# Processing Record 46 of Set 12 | atherton
# Processing Record 47 of Set 12 | upata
# Processing Record 48 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 49 of Set 12 | sindor
# Processing Record 50 of Set 12 | yumen
# Processing Record 1 of Set 13 | bonavista
# Processing Record 2 of Set 13 | rapar
# Processing Record 3 of Set 13 | choma
# Processing Record 4 of Set 13 | goiatuba
# Processing Record 5 of Set 13 | berestechko
# Processing Record 6 of Set 13 | gorokhovets
# Processing Record 7 of Set 13 | fethiye
# Processing Record 8 of Set 13 | loa janan
# Processing Record 9 of Set 13 | boa vista
# Processing Record 10 of Set 13 | yazman
# Processing Record 11 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 12 of Set 13 | vanimo
# Processing Record 13 of Set 13 | naze
# Processing Record 14 of Set 13 | primore
# City not found. Skipping...
# Processing Record 15 of Set 13 | aberfeldy
# Processing Record 16 of Set 13 | labranzagrande
# Processing Record 17 of Set 13 | havoysund
# Processing Record 18 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 13 | daru
# Processing Record 20 of Set 13 | verkhnyaya toyma
# Processing Record 21 of Set 13 | qasigiannguit
# Processing Record 22 of Set 13 | beyneu
# Processing Record 23 of Set 13 | kununurra
# Processing Record 24 of Set 13 | pouembout
# Processing Record 25 of Set 13 | roald
# Processing Record 26 of Set 13 | solnechnyy
# Processing Record 27 of Set 13 | unity
# Processing Record 28 of Set 13 | harrison
# Processing Record 29 of Set 13 | marion
# Processing Record 30 of Set 13 | svetlyy
# Processing Record 31 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 13 | damietta
# Processing Record 33 of Set 13 | mount darwin
# Processing Record 34 of Set 13 | hay river
# Processing Record 35 of Set 13 | alamosa
# Processing Record 36 of Set 13 | marsabit
# Processing Record 37 of Set 13 | luena
# Processing Record 38 of Set 13 | moerai
# Processing Record 39 of Set 13 | channel-port aux basques
# Processing Record 40 of Set 13 | borlange
# City not found. Skipping...
# Processing Record 41 of Set 13 | aguadilla
# Processing Record 42 of Set 13 | san lazaro
# Processing Record 43 of Set 13 | jumla
# Processing Record 44 of Set 13 | oia
# Processing Record 45 of Set 13 | teya
# Processing Record 46 of Set 13 | jiuquan
# Processing Record 47 of Set 13 | ajuchitlan
# Processing Record 48 of Set 13 | burnie
# Processing Record 49 of Set 13 | okha
# Processing Record 50 of Set 13 | bambanglipuro
# Processing Record 1 of Set 14 | sfantu gheorghe
# Processing Record 2 of Set 14 | hammerfest
# Processing Record 3 of Set 14 | port hardy
# Processing Record 4 of Set 14 | monte alegre de sergipe
# Processing Record 5 of Set 14 | honningsvag
# Processing Record 6 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 7 of Set 14 | port shepstone
# Processing Record 8 of Set 14 | kargapolye
# City not found. Skipping...
# Processing Record 9 of Set 14 | macas
# Processing Record 10 of Set 14 | constantine
# Processing Record 11 of Set 14 | moron
# Processing Record 12 of Set 14 | tambun
# Processing Record 13 of Set 14 | bone
# Processing Record 14 of Set 14 | kautokeino
# Processing Record 15 of Set 14 | ketchikan
# Processing Record 16 of Set 14 | shatsk
# Processing Record 17 of Set 14 | karasuk
# Processing Record 18 of Set 14 | port-gentil
# Processing Record 19 of Set 14 | maputo
# Processing Record 20 of Set 14 | keetmanshoop
# Processing Record 21 of Set 14 | koungou
# Processing Record 22 of Set 14 | bagdarin
# Processing Record 23 of Set 14 | cocorit
# Processing Record 24 of Set 14 | buchanan
# Processing Record 25 of Set 14 | tuy hoa
# Processing Record 26 of Set 14 | darhan
# Processing Record 27 of Set 14 | walvis bay
# Processing Record 28 of Set 14 | edremit
# Processing Record 29 of Set 14 | tilichiki
# Processing Record 30 of Set 14 | porto belo
# Processing Record 31 of Set 14 | rassvet
# Processing Record 32 of Set 14 | inhambane
# Processing Record 33 of Set 14 | rabo de peixe
# Processing Record 34 of Set 14 | adrar
# Processing Record 35 of Set 14 | jonesboro
# Processing Record 36 of Set 14 | dzerzhinsk
# Processing Record 37 of Set 14 | pravec
# City not found. Skipping...
# Processing Record 38 of Set 14 | burica
# City not found. Skipping...
# Processing Record 39 of Set 14 | kirovskiy
# Processing Record 40 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 41 of Set 14 | pudozh
# Processing Record 42 of Set 14 | biak
# Processing Record 43 of Set 14 | muli
# Processing Record 44 of Set 14 | broome
# Processing Record 45 of Set 14 | galveston
# Processing Record 46 of Set 14 | la rioja
# Processing Record 47 of Set 14 | galesong
# Processing Record 48 of Set 14 | uchaly
# Processing Record 49 of Set 14 | imbituba
# Processing Record 50 of Set 14 | sainte-claire
# Processing Record 1 of Set 15 | quesnel
# Processing Record 2 of Set 15 | el alto
# Processing Record 3 of Set 15 | bernalillo
# Processing Record 4 of Set 15 | ankpa
# Processing Record 5 of Set 15 | haljala
# Processing Record 6 of Set 15 | akdepe
# Processing Record 7 of Set 15 | mangrol
# Processing Record 8 of Set 15 | moussoro
# Processing Record 9 of Set 15 | churapcha
# Processing Record 10 of Set 15 | yuancheng
# Processing Record 11 of Set 15 | canguaretama
# Processing Record 12 of Set 15 | banjar
# Processing Record 13 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 14 of Set 15 | micheweni
# Processing Record 15 of Set 15 | chor
# Processing Record 16 of Set 15 | rovenki
# Processing Record 17 of Set 15 | batticaloa
# Processing Record 18 of Set 15 | pokrovka
# Processing Record 19 of Set 15 | alberton
# Processing Record 20 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 15 | tenenkou
# Processing Record 22 of Set 15 | ixtapa
# Processing Record 23 of Set 15 | akmene
# Processing Record 24 of Set 15 | mayya
# Processing Record 25 of Set 15 | uruguaiana
# Processing Record 26 of Set 15 | miri
# Processing Record 27 of Set 15 | coachella
# Processing Record 28 of Set 15 | tabialan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 663

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Rikitea      PF -23.1203 -134.9692     78.62        77          98
# 1        Uyovu      TZ  -3.2833   31.5258     63.77        88          84
# 2  New Norfolk      AU -42.7826  147.0587     64.90        53          56
# 3       Hobart      AU -42.8794  147.3294     65.26        82          75
# 4       Aitape      PG  -3.1374  142.3475     85.41        68          71
# 5      Talnakh      RU  69.4865   88.3972    -34.80        97          46
# 6      Ushuaia      AR -54.8000  -68.3000     46.06        61           0
# 7       Albany      US  42.6001  -73.9662     40.95        93         100
# 8      Qaanaaq      GL  77.4840  -69.3632    -17.63        85         100
# 9    Vestmanna      FO  62.1564   -7.1664     34.72        87         100
#
#    Wind Speed Current Description
# 0       14.23          light rain
# 1        1.39          light rain
# 2        5.01       broken clouds
# 3       13.80       broken clouds
# 4        8.55       broken clouds
# 5        1.30    scattered clouds
# 6        3.44          light rain
# 7        2.19     overcast clouds
# 8        5.17     overcast clouds
# 9        1.14     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Rikitea      PF -23.1203 -134.9692     78.62        77          98
# 1        Uyovu      TZ  -3.2833   31.5258     63.77        88          84
# 2  New Norfolk      AU -42.7826  147.0587     64.90        53          56
# 3       Hobart      AU -42.8794  147.3294     65.26        82          75
# 4       Aitape      PG  -3.1374  142.3475     85.41        68          71
# 5      Talnakh      RU  69.4865   88.3972    -34.80        97          46
# 6      Ushuaia      AR -54.8000  -68.3000     46.06        61           0
# 7       Albany      US  42.6001  -73.9662     40.95        93         100
# 8      Qaanaaq      GL  77.4840  -69.3632    -17.63        85         100
# 9    Vestmanna      FO  62.1564   -7.1664     34.72        87         100
#
#    Wind Speed Current Description
# 0       14.23          light rain
# 1        1.39          light rain
# 2        5.01       broken clouds
# 3       13.80       broken clouds
# 4        8.55       broken clouds
# 5        1.30    scattered clouds
# 6        3.44          light rain
# 7        2.19     overcast clouds
# 8        5.17     overcast clouds
# 9        1.14     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
